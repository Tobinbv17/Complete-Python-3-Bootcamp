# %% [markdown]
# ___
#
# <a href='https://www.udemy.com/user/joseportilla/'><img src='../Pierian_Data_Logo.png'/></a>
# ___
# <center><em>Content Copyright by Pierian Data</em></center>

# %% [markdown]
# # Object Oriented Programming Challenge
#
# For this challenge, create a bank account class that has two attributes:
#
# * owner
# * balance
#
# and two methods:
#
# * deposit
# * withdraw
#
# As an added requirement, withdrawals may not exceed the available balance.
#
# Instantiate your class, make several deposits and withdrawals, and test to make sure the account can't be overdrawn.

# %%
class Account:
    def __init__(self,owner, balance):
      self.owner = owner
      self.balance = balance

    def __str__(self):
      return (f'Account owner is : {self.owner} \nAccount balance is : {self.balance}')

    def deposit(self,amount):

      self.balance = self.balance + amount
      print (f'Deposit accepted, add {amount} to your account')

    def withdraw(self,amount):
      if amount > self.balance:
        print ('Funds Unavailable!')

      else:
        self.balance = self.balance - amount
        print (f"Withdraw accepted, withdraw {amount} from your account")

# %%
# 1. Instantiate the class
acct1 = Account('Jose',100)

# %%
# 2. Print the object
print(acct1)
# Out:
# Account owner is : Jose
# Account balance is : 100

# %%
# 3. Show the account owner attribute
acct1.owner
# Out:
# 'Jose'

# %%
# 4. Show the account balance attribute
acct1.balance
# Out:
# 100

# %%
# 5. Make a series of deposits and withdrawals
acct1.deposit(50)
# Out:
# Deposit accepted, add 50 to your account

# %%
acct1.withdraw(75)
# Out:
# Withdraw accepted, withdraw 75 from your account

# %%
# 6. Make a withdrawal that exceeds the available balance
acct1.withdraw(500)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-118184507.py in <cell line: 0>()
#       1 # 6. Make a withdrawal that exceeds the available balance
# ----> 2 acct1.withdraw(500)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ## Good job!
